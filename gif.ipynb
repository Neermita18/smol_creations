# %% [markdown]
# <a href="https://colab.research.google.com/github/Neermita18/smol_creations/blob/main/gif.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## GIF Maker!

# %%
import imageio.v3 as iio
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
filenames = ['images.jpg', 'images2.jpg']
images = [ ]

image1= iio.imread("images.jpg")
image2= iio.imread("images2.jpg")
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

axes[0].imshow(image1)
axes[0].axis('off')
axes[0].set_title('First Image')


axes[1].imshow(image2)
axes[1].axis('off')
axes[1].set_title('Second Image')
for filename in filenames:
  images.append(iio.imread(filename))


iio.imwrite('team.gif', images, duration = 500, loop = 0)

# %% [markdown]
# ![team](/content/team.gif "segment")
